# %%
import pandas as pd

# load into df:
fpath = 'C:/Users/Bizon/OneDrive/Data Incubator/12 Day Program/'
fname = 'Value_of_Energy_Cost_Savings_Program_Savings_for_Businesses_-_FY2020.csv'

df_nyc = pd.read_csv(fpath + fname) #, dtype={'Number of Past Prescriptions': str}
df_nyc.head()
# Out:
#                                Company Name    company contact  \
# 0                            1 State Street      David Neiburg
# 1                            100 Church LLC  Edward A. Carroll
# 2                      100 Wall Investments       Jerry Branam
# 3               1-10 Bush Terminal Owner LP     Andrew Kimball
# 4  120 Broadway Acquisitions JV, LLC (Ldmk)        Carl Letich
#
#                company email company phone                Address      City  \
# 0     eskoblo@energyspec.com    7186779077          1114 Avenue J  Brooklyn
# 1                        NaN    2125663000      100 Church Street        NY
# 2                        NaN    2122487160         96 Wall Street  New York
# 3  akimball@industrycity.com    3474178429  220 36th St, Suite 2A  Brooklyn
# 4      clettich@silvprop.com    2124064020           120 Broadway  New York
#
#   State  Postcode    Industry  \
# 0    NY     11230  Commercial
# 1    NY     10007  Commercial
# 2    NY     10005    Landlord
# 3    NY     11232    Landlord
# 4    NY     10271  Commercial
#
#                                       Industry descr  ...  \
# 0                                  35 story building  ...
# 1                                          21 Floors  ...
# 2                                                NaN  ...
# 3  Special Eligible Premises for eligible businesses  ...
# 4                                                NaN  ...
#
#   Savings from beginning receiving benefits   Borough   Latitude  Longitude  \
# 0                                    349.78  Brooklyn  40.624784 -73.964920
# 1                              4,423,698.05  New York  40.712968 -74.009490
# 2                              1,814,542.62  New York  40.705052 -74.007199
# 3                                  6,755.31  Brooklyn  40.656061 -74.007334
# 4                              3,293,055.08  New York  40.708546 -74.011041
#
#   Community Board Council District Census Tract        BIN           BBL  \
# 0           314.0             44.0        534.0  3179818.0  3.067130e+09
# 1           101.0              1.0         21.0  1001409.0  1.001250e+09
# 2           101.0              1.0          7.0  1000875.0  1.000380e+09
# 3           307.0             38.0          2.0  3398687.0  3.006950e+09
# 4           101.0              1.0          7.0  1001026.0  1.000478e+09
#
#                                       NTA
# 0                                 Midwood
# 1  SoHo-TriBeCa-Civic Center-Little Italy
# 2       Battery Park City-Lower Manhattan
# 3                        Sunset Park West
# 4       Battery Park City-Lower Manhattan
#
# [5 rows x 26 columns]

# %%
df_nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 26 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Company Name                               450 non-null    object
#  1   company contact                            450 non-null    object
#  2   company email                              433 non-null    object
#  3   company phone                              450 non-null    object
#  4   Address                                    450 non-null    object
#  5   City                                       450 non-null    object
#  6   State                                      450 non-null    object
#  7   Postcode                                   450 non-null    int64
#  8   Industry                                   450 non-null    object
#  9   Industry descr                             434 non-null    object
#  10  Company Type                               450 non-null    object
#  11  Current fulltime                           446 non-null    object
#  12  Job created                                11 non-null     float64
#  13  Job retain                                 14 non-null     object
#  14  Effective Date                             450 non-null    object
#  15  Total Savings                              450 non-null    object
#  16  Savings from beginning receiving benefits  450 non-null    object
#  17  Borough                                    450 non-null    object
#  18  Latitude                                   409 non-null    float64
#  19  Longitude                                  409 non-null    float64
#  20  Community Board                            409 non-null    float64
#  21  Council District                           409 non-null    float64
#  22  Census Tract                               409 non-null    float64
#  23  BIN                                        401 non-null    float64
#  24  BBL                                        401 non-null    float64
#  25  NTA                                        409 non-null    object
# dtypes: float64(8), int64(1), object(17)
# memory usage: 91.5+ KB

# %%
#1. How many different companies are represented in the data set?
df_nyc['Company Name'].value_counts()
# 439 companies
# Out:
# FEDERAL EXPRESS                        3
# JetBlue Airways, Corp.                 2
# KEPCO, INC.                            2
# FRESH DIRECT LLC                       2
# MEDITERRANEAN GYRO PRODUCTS            2
#                                       ..
# Eastern Plating, Inc.                  1
# Eastern Effects, Inc.                  1
# EASTERN CONCEPTS, INC.                 1
# East Coast Envelope & Graphics, LLC    1
# Wurtec Incorporated                    1
# Name: Company Name, Length: 439, dtype: int64

# %%
# another way:
df_nyc['Company Name'].unique()

#remove rows with repeat Company Names:
#df_nyc = df_nyc.loc[df_nyc['Company Name'].sort_values().index].drop_duplicates('Company Name', keep='first')
# Out:
# array(['1 State Street', '100 Church LLC', '100 Wall Investments',
#        '1-10 Bush Terminal Owner LP',
#        '120 Broadway Acquisitions JV, LLC (Ldmk)', '120 Wall Street, LLC',
#        '139 ACA Realty, Inc.',
#        '141 Lake Avenue Realty c/o JR Produce, Inc.',
#        '14-10 123rd Street LLC', '183 Lorriane Street LLC',
#        '195 Broadway, LLC', '2 Rector Street (NY) LLC',
#        '21st Century Optics, Inc.', '25 Broadway (Ldmk)', '4Over4.com',
#        '538-540 West 35 Corp', '55 Water, LLC', '72andSunny Partners LLC',
#        '75 Broad Street', 'A & L Scientific Corp.',
#        'A.K.S. International, Inc', 'ABEL CINE TECH, INC.',
#        'ABIGAL PRESS, INC.', 'Accenture LLP',
#        'Achieve Beyond, Inc. (Formerly Bilinguals, Inc.)',
#        'Action Carting Environmental Services, Inc', 'ADP Oak Point LLC',
#        'AECOM Technical Services Inc', 'Aesthetonics, Inc.',
#        'AFC INDUSTRIES, INC.', 'African Services Committee, Inc.',
#        'Aids Vaccine Advocacy Coalition',
#        'ALADDIN BAKERS, INC/Bread Head, LLC.',
#        'Albert Einstein College of Medicine R&D',
#        'Alchemy Paintworks LLC', 'All City Metal, Inc.',
#        'ALLE PROCESSING CORP.', 'ALLIED SAMPLE CARDS CO., INC.',
#        'Allison Eden Studios', 'Allstate Medical Supplies LLC',
#        'ALRUE IMPORT COPR.', 'Amazon Corporate LLC',
#        'American Bridge Company', 'American Folk Art Museum',
#        'American Torque, Inc.', 'American Transit Insurance Co',
#        'AMY SCHERBER, INC.', 'ANHEUSER BUSH',
#        'Apex Logistics International (JFK), Inc',
#        'Apple Bank for Savings', 'Approved Oil Co. of Brooklyn, Inc.',
#        'APTHORP CLEANERS, INC.', 'Arista Coffee, Inc.',
#        'Armada New York LLC', 'ARROW LINEN SUPPLY CO.',
#        'Asymptote Architecture, PLLC', 'B. Thayer Associates',
#        'B.C.S. International Corporation', 'B.P. AIR CONDITIONING CORP/',
#        'BACO ENTERPRISES, INC.', 'BALDOR SPECIALTY FOOD',
#        'BANNER SMOKED FISH, INC.', 'BARK FRAMEWORKS, INC.',
#        'BARONE STEEL FABRICATORS, INC.', 'Barry X. Ball Studio, Inc.',
#        'BCGA Concept Corporation', 'Belmont Metals', 'BENSON MILLS, INC.',
#        'Bermuda Motor Car Renting Co.', 'BEST CASE & ACCESSORIES, INC.',
#        'Best Choice Trading Corp', 'Best Mounting Corp.',
#        'Bestec Concept, Inc.', 'Bigheavy Studios',
#        'BILLIE-ANN PLASTICS PKGING CORP', "BIMMY'S LLC",
#        'Birns Telecommunication, Inc.', 'Bjork Carle Woodworking, Inc.',
#        'Blumberg Excelsior, Inc.', 'Bo Bo Poultry Market, Inc.',
#        'BoyceTechnologies, Inc.', 'Breuckelen Distilling Co., Inc.',
#        'BRIDGE PLAZA ASSOCIATES LLC', 'Bronx River Media Group, LLC',
#        'Bronx Westchester Tempering, Inc',
#        'Brooklyn Immuno Therapeutics LLC', 'Brooklyn Nets',
#        'BROOKLYN UNION GAS COMPANY', 'Brooklyn Wholesale Bakery LLC',
#        'Brunetti & Brunetti LLC', 'Burden, LLC',
#        'CAMEO METAL PRODUCTS, INC.', 'Caples Jefferson Architects, PC',
#        'Carlton House Restoration, Inc.', 'CARNEGIE LINEN SERVICES, INC.',
#        'Casual Films, Inc.', 'CAVCO ROOFING, INC.', 'Chase Bank, N.A.',
#        'Chelsea Plastics Corp/Plexi-Craft Quality Products',
#        "Christie's Fine Art Storage Services, Inc", "Christie's Inc.",
#        'Citibank, N.A.', 'City Baking LLC aka Bakery City LLC',
#        'CN MANAGEMENT LLC', 'Collins Building Services, Inc.',
#        'COMFORT BEDDING', 'Comp Trading LLC',
#        'Computer Services Group, Inc.', 'Concept Farm, Inc.',
#        'Constitution Realty LLC (Ldmk)', 'COOL WIND VENTILATION CORP.',
#        'CORONET PARTS MANUFACTURING CO. INC', 'COSMOS COMMUNICATIONS',
#        'Cotronics Corporation', 'Crepini, LLC',
#        'Crystal Lake Trading, Inc.', 'Cyracom International, Inc.',
#        'D.C. CENTER CORP', 'D.S. & Durga LLC', 'DAIRYLAND USA CORP.',
#        'Daniel Scuderi', 'Dart Medical Labortory, Inc.',
#        'Dasny Mechanical Inc.', 'DBAB Wall Street, LLC.',
#        'DCD Marketing Ltd.', 'Deep Draw Silver, Inc.',
#        'Delvi Realty Corp.', 'DEPOSITORY TRUST COMPANY',
#        'Deutsche Bank Securities, Inc.', 'DI DOMENICO & PARTNERS LLP',
#        'DIAMOND STREET PROPERTIES', 'Dinas Distribution Corp.',
#        'Down East & Seafood, Inc.', 'Dr. Smood New York Production LLC',
#        'Duce Construction Corp.', 'Dundy Glass & Mirror Corp.',
#        'DURA FOAM, INC.', 'E&C Property Holdings South, Inc.',
#        'E. J. York, Inc.', 'East Coast Envelope & Graphics, LLC',
#        'EASTERN CONCEPTS, INC.', 'Eastern Effects, Inc.',
#        'Eastern Plating, Inc.', 'Eclectic/Encore Properties, Inc.',
#        'EDISON PRICE, INC.', 'EMG Media, Inc.', 'Empress Media, Inc.',
#        'Epic Pharma LLC', 'Estee Lauder Companies, Inc',
#        'Evergreen 105 LLC', 'EverGreene Architectural Arts, Inc.',
#        'Export Trade of America, Inc.', 'E-Z Ink, Inc.',
#        'Fairway Bakery LLC', "FALCONE'S COOKIELAND, LTD.",
#        'FAT WITCH BAKERY, INC.', 'Faviana International Inc',
#        'FAVORITE PLASTICS CO., INC.', 'Fay Da Manufacturing Corp.',
#        'FEDERAL EXPRESS', 'Fidelity Payment Services Ltd.',
#        'First United Distribution Corp.', 'Food Saver, New York, Inc.',
#        'FoodFest Depot LLC', 'FOREST CITY PIERREPONT ASSOCIATES',
#        'Foster Reeve & Associates, Inc.',
#        'Franke Gottsegen & Cox Architect.',
#        'FRED GELLER ELECTRICAL, INC.', 'FRESH DIRECT LLC',
#        'G & G Manhattan Fruitier, Inc.',
#        'Gailer Stamping & Die Cutting, LLC', 'GBW LLC', 'gCreate LLC',
#        'Global Container Terminal (GCT) New York LP', 'Globus Cork, Inc.',
#        'Goldstein Capital Corp', 'Gotham Greens Gowanus LLC',
#        'GOTHAM SEAFOOD CORP.', 'GOURMET BOUTIQUE LLC',
#        'Graf & Lewent Architects LLP', 'Graham Windham Organization',
#        'GRAND MERIDIAN PRINTINGS, INC.',
#        'Grandstand Sports & Memorabilia, Inc.', 'Greenfelds LLC',
#        'Greenpoint Avenue Realty LLC', 'GREENPOINT GROUP, LLC',
#        'Grimm Ales LLC', 'Gustav Restoration LLC',
#        'HALE & HEARTY SOUPS, LLC', 'Hall Street Storage LLC',
#        'HALMARK ARCHITECTUAL FINISHING', 'HALO  Recognition, Inc',
#        'Harry Brainum Jr., Inc.', 'HEINSEN PRODUCTS, INC.',
#        'HERCULES HEAT TREATING CORPORATION,', 'HI INTERIORS, INC.',
#        'Hi Tech Metals, Inc.', 'Highline Locations LLC',
#        'Hindustan Granites, Inc.', 'HIRD/BLAKER, INC.',
#        'HI-TECH RESOURCE RECOVERY', 'House of Spices (India), Inc',
#        'Hudson Moving & Storage Co., Inc.', 'HUSH Studios, Inc.',
#        'Hydromx, Inc.', 'I. AM. Malia Mills, LLC', 'Ideas by Barbara',
#        'IDL Communications and Electric, Inc', 'IEH CORPORATION',
#        'Ikea Holding U.S., Inc.', 'Inner Gaze Furniture Designs, Inc.',
#        'Insek Design', 'Iron Mountain', 'J & B Realty LLC',
#        'J & J Johnson General Contracting Co., Inc.',
#        'J&S LICATA BROTHERS, INC', 'J. Crew Group, Inc.',
#        'Jacques Torres Manufacturing LLC',
#        'JAMES CARPENTER DESIGN ASSOC., INC.', 'JANUS MANAGEMENT, INC.',
#        'Japanese Food Depot LLC', 'JDB Market Corp.',
#        'JetBlue Airways, Corp.', 'Jetro Cash & Carry Enterprises LLC',
#        'Jewels For Me, Inc.', 'Johnson Ingraham Associates',
#        'Josiah McElheny Studio', 'JPR Mechanical Inc.',
#        'JUST BAGELS/ NORDQUIST ENTERPRISES', 'K Line Logistics (USA) Inc',
#        'K M S CONTRACTING INC dba Sure Iron Works',
#        'K. K. Machine Company, Inc.', 'Karr Graphics Corp.',
#        'KAS PRODUCTION CENTER LLC', 'Katiroll Company LLC, The',
#        'KAUFMAN Astoria Studios', 'KEPCO, INC.', 'Kickstarter, PBC',
#        'Kingsland 359 LLC', 'Kintetsu World Express (U.S.A.), Inc.',
#        'Kleins Naturals Ltd.', 'KONG KEE REALTY CORP',
#        'Kopelevich & Feldsherova, PC', 'Krasnyi Oktybar, Inc.',
#        'KRINOS FOODS, INC.', 'LaFarge North America',
#        'Lafayette 148, Inc', 'LAFAYETTE GRINDING CORP.',
#        'LEE SPRINGS COMPANY', 'Leemor Lilly, LLC',
#        'Lida Collection, Inc.', 'Liquid 8 Technology, Inc.',
#        'Liquid Knits, Inc.', 'Livestream LLC', 'Lobonav Corp',
#        'Long Island Concrete, Inc.', "M & R CPA's LLP",
#        'M. SLAVIN & SONS, LTD.', 'Mack Glassnauth Iron Works, Inc.',
#        'MADAME PAULETTE, LIC, LLC', 'MADELAINE CHOCOLATE NOVELTIES, INC.',
#        'Magellan Aerospace New York, Inc', 'Marathon Energy Corp',
#        "Maribel's Sweets, Inc.", 'Maric Mechanical Inc.',
#        'Marina Ice Cream Corp.', 'MARJAM SUPPLY CO., INC.',
#        'Matros Automated Electrical Const.', 'McInnis USA Inc.',
#        'Mechoshade Systems, Inc.', 'MEDITERRANEAN GYRO PRODUCTS',
#        'Mesorah Publications, Ltd & Sefercraft, Inc',
#        'Michael C. Fina Co, Inc', 'MKJ Communications, Inc',
#        'Modern Windor & Door, Inc.', 'MONDIAL AUTOMOTIVE, INC.',
#        'MONTEBELLO FOOD CORP', 'Montefiore Medical Center',
#        'Music Arhive Collection LLC Floor 2 and 3', 'MYT Works, Inc',
#        'National Acoustics, Inc.', 'National Bias Binding Corp.',
#        'National Leather and Shoe Findings Co.',
#        'Natuzzi Bros Ice Co, Inc', 'Neighborhood Eigth Avenue LLC',
#        "Neuman's Kitchen", 'New Concepts of NY LLC', 'New Heydenryk, LLC',
#        'NEW PALACE PAINTERS SUPPLY CO., INC.', 'New Water Street  Corp',
#        'NEW YORK BLOOD CENTER',
#        'New York Digital Color Lithographers Printers, Inc',
#        'New York Fragrance', 'New York Insulation, Inc.',
#        'NEW YORKER WHOLESALE BAGELS, INC.', 'Noho Health, Inc',
#        'Nova Offset Corp', 'Novare LLC', 'NOVELTY CRYSTAL CORP.',
#        'Novo Arts Associates, Inc.', 'NULUX INDUSTRIES',
#        'NY Telephone #11194', 'Octopus Garden, Inc/Octopus Two Corp',
#        'Office 118 Equities LLC', 'Oh Nuts Warehousing, Inc.',
#        'One Girl Cookies, Ltd.', 'Other Half Brewing, Co,',
#        'Oven Artisans,  Inc.', "Pain D'Avignon III Ltd.",
#        'Paper Enterprises, Inc.', 'Parallel Development Ltd.',
#        'Parkway Equipment Handlers, Inc.', 'Parsons-Meares Ltd.',
#        'PEERLESS IMPORTERS, INC.', 'Pelican Bay Ltd.',
#        'PEPSI COLA BOTTLING CO., OF NY', 'PetCare Rx., Inc.',
#        'Phoenix Beverage', 'Picasso/Hoops, I Love New York LLC',
#        'Picture Farm II, LLC', 'Pinto & Teger Electric',
#        'POOK DIEMONT & OHL, INC.', 'Poster Printers, Inc.',
#        'Postmeds, Inc.', 'Premium Millwork, Inc.',
#        'Presentation Products, Inc.', 'Proxima, Inc',
#        'Quality Casting, Inc.', 'R Simon Design, Inc.',
#        'Rainbow Plastics, Inc.', 'Rareform Carting, Inc.',
#        'RDS Delivery Services, Co., Inc.', 'Real Coffee Roasters',
#        'Red Rabbit LLC', 'Rhonda Feinman Custom Frames, Inc.',
#        'Richards Plumbing & Heating Co., Inc.',
#        "ROGELIO'S WAY/DIGITAL LAUNDRY", 'Rogers Surveying PLLC.',
#        'Rolex Watch USA, Inc.', 'Rony Elka Vardi, Inc', 'Roxy Paine LLC',
#        'ROYAL AIRLINE LAUNDRY SERVICES CORP', 'ROYAL DEVELOPMENT, INC.',
#        'Rufus Corporation', 'RUGUS REALTY, INC. DBA MISS GRIMBLE',
#        'Russ Ops LLC', 'RWS & Associates Entertainment',
#        'S&L AEROSPACE METALS LLC', 'Safe Art Sat, Inc.',
#        'Sculpture House Casting, Inc.', 'SDC Designs LLC',
#        'Sharan Builders, Inc.', 'Shloms Heimish Corp',
#        'SIGNS DECAL CORP.', 'SILLY PHILLIE CREATIONS, INC.',
#        'Silver Hill Atelier, LLC', 'SILVERCUP Services LLC',
#        'Silverman Ceramics, LLC/Alsio Design, LLC',
#        'SIM Digital New York', 'Simone Management Group, Inc.',
#        "SIMON''S HARDWARE", 'Sizzal, LLC',
#        'Sky High Murals - Colossal Media, Inc.',
#        'Skyline Restoration, Inc.', 'Skyline Windows, LLC',
#        'SoHarlem  Inc.', 'Spaeth Design, Inc.', 'Spectrum',
#        'Spin Master, Inc.', 'Square Roots Urban Growers, Inc.',
#        'SSJ Contracting', 'SSP America, Inc.', 'STALLION, INC.',
#        'Stand And Build LLC', 'StinkDigital USA LLC', 'Studio UG',
#        'Sunset Park Farm LLC', "SWEET SAM'S BAKING CO., LLC",
#        'T & M Richardson Street LLC', 'T & Z Properties LLC',
#        'TECHNICAL LIBRARY SERVICE, INC.', 'TEI Group',
#        'The Bronx Brewery LLC', 'The Dime Savings Bank of Williamsburg',
#        'The Gluck Architectural Collaborative, P.C.',
#        'The Handy Tool & Mfg. Co., Inc.', 'The Lobster Place, Inc.',
#        'The Woodwrights', 'THEODOSIOU', 'TI Ozone Park Storage LLC',
#        'TIN SHING REALTY, INC.', 'Ti-Tone Communications, Inc.',
#        'Toner Quest, Inc.', 'Tracy Watts, Inc.',
#        'TRANSCONTINENTAL ULTRA FLEX , INC.', 'Transmitter Brewing LLC',
#        'Treasure Asset Storage LLC', 'Tristate Plumbing Services, Inc.',
#        'Tropicana Products Sales, Inc.', "TUFO'S WHOLESALE DAIRY INC.",
#        'Twin Marquis, Inc', 'Twoseven Inc.', 'Ulano Corporation',
#        'ULTRA CREATIVE CORP.', 'United Air Conditioning Corp',
#        'United Nations Federal Credit Union', 'Uniworld Group Inc.',
#        'Urban Archaeology, LTD', 'Urban Green LLC',
#        'USTA NATIONAL TENNIS CENTER, INC.', 'UTC Corporation',
#        'Valon Realty, LLC', 'Van Blarcom Closures Inc',
#        'VANBRO CORPORATION', 'VaynerMedia LLC',
#        'Vera Institute of Justice, Inc.', 'Vernon Lakes Partners',
#        'VISITING NURSE SERVICE OF NEW YORK', 'VISY PAPER RECYCLING',
#        'VIVA TIME CORP.', 'W Architecture & Landscape Architecture LLC',
#        'WALDORF BAKERY, INC. DBA MAURICE', 'WATER LILIES FOOD, INC.',
#        'WATERMARK DESIGN, LTD.', 'Weapons Specialist Ltd',
#        'Werwaiss & Co., Inc.', 'WHBI LLC',
#        'Whipped Pastry Boutique, Inc.', 'White Coffee Corporation',
#        'WHITEHEAD COMPANY, INC.', 'WIGGBY PRECISION MACHINE CORP.',
#        'Wild Edibles, Inc.', 'William Hird & Co., Inc.',
#        'Williams Sonoma, Inc.', 'WONTON FOOD, INC.', 'Wood Works',
#        'WorldWide Plumbing Supply, Inc.', 'WUD Furniture LLC',
#        'Wurtec Incorporated'], dtype=object)

# %%
# 2. What is the total number of jobs created for businesses in Queens?
df_nyc.query('City.str.startswith("Q").values')
# shows two spellings of Queens: as Queens and QUEENS
# Out:
#                           Company Name    company contact  \
# 15                538-540 West 35 Corp     Richard Silver
# 19              A & L Scientific Corp.     Anthony Vicari
# 20           A.K.S. International, Inc    Tomislav nNgalo
# 37               ALLE PROCESSING CORP.      Sam HOLLANDER
# 45               American Torque, Inc.    Robert McCarthy
# ..                                 ...                ...
# 420  USTA NATIONAL TENNIS CENTER, INC.     DANIEL ZAUSNER
# 433            WATER LILIES FOOD, INC.          Peter Lee
# 435             Weapons Specialist Ltd  Richard  Washburn
# 436               Werwaiss & Co., Inc.     John  Wersaiss
# 439           White Coffee Corporation     Jonathan White
#
#                     company email company phone  \
# 15             tankman220@aol.com    2127366618
# 19       service@alscientific.com    7187568100
# 20   tnogalo@aksinternational.com        332313
# 37    halbycpa@alleprocessing.com    7188942000
# 45               Amtorq@gmail.com    7185262433
# ..                            ...           ...
# 420              crowley@usta.com    7187606237
# 433  peterlee@waterliliesfood.com    7187778899
# 435   ryder@weaponspecialists.com    2129417696
# 436          JW@werwaissandco.com    9173187800
# 439            jw@whitecoffee.com    7182047900
#
#                                  Address    City State  Postcode  \
# 15                       11-42 46th Road  Queens    NY     11101
# 19                     88-05 76th Avenue  Queens    NY     11385
# 20                     37-04 19th Avenue  Queens    NY     11105
# 37   54-58 56TH DR. & 5820-5880  MAURICE  Queens    NY     11378
# 45                   105-22 150th Street  Queens    NY     11435
# ..                                   ...     ...   ...       ...
# 420         FLUSHING MEADOWS-CORONA PARK  Queens    NY     11368
# 433                    45-10 19TH AVENUE  Queens    NY     11105
# 435               47-40 Metropolitan Ave  Queens    NY     11385
# 436              22-15 43rd Ave, Ste 300  Queens    NY     11101
# 439                    18-35 38th Street  Queens    NY     11105
#
#                              Industry  \
# 15                      Manufacturing
# 19                      Manufacturing
# 20                      Manufacturing
# 37                      Manufacturing
# 45                      Manufacturing
# ..                                ...
# 420                        Commercial
# 433                     Manufacturing
# 435  Wholesale/Warehouse/Distribution
# 436                        Commercial
# 439                     Manufacturing
#
#                                         Industry descr  ...  \
# 15                          steel, wood & cement tanks  ...
# 19   fabricates and services biotech medical equipment  ...
# 20    metal contracting & fabricator of metal products  ...
# 37                                        MANUFACTURER  ...
# 45             mfg torque converters and related parts  ...
# ..                                                 ...  ...
# 420                             ADMINISTRATIVE OFFICES  ...
# 433                                       MANUFACTURER  ...
# 435    Studio Property Rental, Motion Picture business  ...
# 436                             Real estate management  ...
# 439  Mfg specialty coffee/import & distribute coffe...  ...
#
#     Savings from beginning receiving benefits Borough   Latitude  Longitude  \
# 15                                  56,744.11  Queens  40.745510 -73.949497
# 19                                  35,540.16  Queens  40.707402 -73.862139
# 20                                  20,691.63  Queens  40.779184 -73.900755
# 37                               3,645,626.13  Queens        NaN        NaN
# 45                                  73,037.27  Queens  40.696796 -73.801885
# ..                                        ...     ...        ...        ...
# 420                               1,849,004.7  Queens        NaN        NaN
# 433                                 927,036.8  Queens  40.776128 -73.896413
# 435                                165,002.94  Queens  40.713695 -73.918990
# 436                                  3,335.97  Queens  40.749987 -73.944311
# 439                                583,542.01  Queens  40.779751 -73.898971
#
#     Community Board Council District Census Tract        BIN           BBL  \
# 15            402.0             26.0          7.0  4436616.0  4.000560e+09
# 19            405.0             30.0        637.0  4094396.0  4.038560e+09
# 20            401.0             22.0      12301.0  4436970.0  4.008120e+09
# 37              NaN              NaN          NaN        NaN           NaN
# 45            412.0             28.0        204.0  4589555.0  4.100620e+09
# ..              ...              ...          ...        ...           ...
# 420             NaN              NaN          NaN        NaN           NaN
# 433           401.0             22.0      12301.0  4014854.0  4.007750e+09
# 435           405.0             34.0        539.0  4548477.0  4.033750e+09
# 436           402.0             26.0         19.0  4005067.0  4.004260e+09
# 439           401.0             22.0      12301.0  4436972.0  4.008130e+09
#
#                                       NTA
# 15   Hunters Point-Sunnyside-West Maspeth
# 19                               Glendale
# 20                               Steinway
# 37                                    NaN
# 45                                Jamaica
# ..                                    ...
# 420                                   NaN
# 433                              Steinway
# 435                             Ridgewood
# 436  Hunters Point-Sunnyside-West Maspeth
# 439                              Steinway
#
# [73 rows x 26 columns]

# %%
# convert all city names to uppercase:
df_nyc['City'] = df_nyc['City'].apply(lambda x: x.upper())

# %%
df_nyc.head()
# Out:
#                                Company Name    company contact  \
# 0                            1 State Street      David Neiburg
# 1                            100 Church LLC  Edward A. Carroll
# 2                      100 Wall Investments       Jerry Branam
# 3               1-10 Bush Terminal Owner LP     Andrew Kimball
# 4  120 Broadway Acquisitions JV, LLC (Ldmk)        Carl Letich
#
#                company email company phone                Address      City  \
# 0     eskoblo@energyspec.com    7186779077          1114 Avenue J  BROOKLYN
# 1                        NaN    2125663000      100 Church Street        NY
# 2                        NaN    2122487160         96 Wall Street  NEW YORK
# 3  akimball@industrycity.com    3474178429  220 36th St, Suite 2A  BROOKLYN
# 4      clettich@silvprop.com    2124064020           120 Broadway  NEW YORK
#
#   State  Postcode    Industry  \
# 0    NY     11230  Commercial
# 1    NY     10007  Commercial
# 2    NY     10005    Landlord
# 3    NY     11232    Landlord
# 4    NY     10271  Commercial
#
#                                       Industry descr  ...  \
# 0                                  35 story building  ...
# 1                                          21 Floors  ...
# 2                                                NaN  ...
# 3  Special Eligible Premises for eligible businesses  ...
# 4                                                NaN  ...
#
#   Savings from beginning receiving benefits   Borough   Latitude  Longitude  \
# 0                                    349.78  Brooklyn  40.624784 -73.964920
# 1                              4,423,698.05  New York  40.712968 -74.009490
# 2                              1,814,542.62  New York  40.705052 -74.007199
# 3                                  6,755.31  Brooklyn  40.656061 -74.007334
# 4                              3,293,055.08  New York  40.708546 -74.011041
#
#   Community Board Council District Census Tract        BIN           BBL  \
# 0           314.0             44.0        534.0  3179818.0  3.067130e+09
# 1           101.0              1.0         21.0  1001409.0  1.001250e+09
# 2           101.0              1.0          7.0  1000875.0  1.000380e+09
# 3           307.0             38.0          2.0  3398687.0  3.006950e+09
# 4           101.0              1.0          7.0  1001026.0  1.000478e+09
#
#                                       NTA
# 0                                 Midwood
# 1  SoHo-TriBeCa-Civic Center-Little Italy
# 2       Battery Park City-Lower Manhattan
# 3                        Sunset Park West
# 4       Battery Park City-Lower Manhattan
#
# [5 rows x 26 columns]

# %%
queens = df_nyc.query('City == "QUEENS"')
queens['Job created'].sum()
# total # of jobs created for businesses in Queens = 90
# Out:
# 90.0

# %%
#3. How many different unique email domains names are there in the data set?
emails = df_nyc['company email'].dropna()
emails
# Out:
# 0         eskoblo@energyspec.com
# 3      akimball@industrycity.com
# 4          clettich@silvprop.com
# 5          jmccalla@silvprop.com
# 6              barbara@dial7.com
#                  ...
# 445     donaldlau@wontonfood.com
# 446         brawnworks@gmail.com
# 447             sheidya@wwps.com
# 448       keren@wudfurniture.com
# 449         bill.popp@wurtec.com
# Name: company email, Length: 433, dtype: object

# %%
# remove everything before the @ sign:
split_emails = emails.apply(lambda x: x.split('@'))

# %%
email_end = []
for email in split_emails:
    if len(email) == 2:
        email_end.append(email[1])
    else:
        email_end.append(email[0])

# %%
df_nyc = df_nyc.loc[pd.notnull(df_nyc['company email'])]

df_nyc = df_nyc.assign(email_endings = email_end)
df_nyc['email_endings'].unique()
#361 unique email domains
# Out:
# array(['energyspec.com', 'industrycity.com', 'silvprop.com', 'dial7.com',
#        'gmail.com', 'atjelectrical.com', 'KLCNY.com', 'am.jll.com',
#        '21st centuryoptics.com', '4over4.com', 'aol.com', 'MEQS.com',
#        'mdc-partners.com', 'alscientific.com', 'aksinternational.com',
#        'abelcine.com', 'abigal.com', 'accenture.com', 'bilingualsino.com',
#        'actioncarting.com', 'aduiepyle.com', 'consultant.aecom.com',
#        'remains.com', 'afcindustries.com', 'africanservices.com',
#        'avac.org', 'aladdinbakery.com', 'yu.edu', 'alchemypaintworks.com',
#        'allcitymetal.com', 'alleprocessing.com', 'netzero.net',
#        'allisoneden.comP', 'allstatemedical.com', 'alrue.com',
#        'amazon.com', 'americanbridge.net', 'folkartmuseum.org',
#        'american-transit.com', 'amysbread.com', 'anhuser-busch.com',
#        'apexglobe.com', 'apple-bank.com', 'approvedoil.com',
#        'aristacoffee.com', 'armadany.com', 'arrowlinen.com',
#        'asymptote.net', 'bthayerassociates.com', 'bcsroyal.com',
#        'bpair.com', 'blindbuildersusa.com', 'baldorfood.com',
#        'barkframeworks.com', 'baronesteel.com', 'barryxball.com',
#        'bcga.com', 'belomtmetals.com', 'bensonmills.com',
#        'bermudalimo.com', 'BESTCASECELLULAR.COM', 'yahoo.com',
#        'bestmounting.com', 'msn.com', 'bigheavystudios.com',
#        'billieannplastics.com', 'bimmys.com', 'earthlink.net',
#        'blumb.com', 'boycetech.com', 'brkdistilling.com',
#        'silvercupstudios.com', 'yorkstudios.com', 'bwtglass.com',
#        'brooklynitx.com', 'jgewitrtzbrooklynnets.com', 'us.ngrid.com',
#        'brooklynbrands.com', 'jonathanburden.com', 'cameometal.com',
#        'capjeff.com', 'carltonhouse.net', 'carnegielinen.com',
#        'casualfilms.com', 'cavcoroofing.com', 'chase.com',
#        'plexi-craft.com', 'christies.com', 'citi.com', 'verizon.net',
#        'cbs-collins.com', 'comfortbeddinginc.com', 'mtmsalescorp.com',
#        'csgny.com', 'conceptfarm.com', 'coolwind.biz', 'coronetparts.com',
#        'cosmoscommunications.com', 'cotronics.com', 'crepini.com',
#        'crystallaketrading.com', 'cyracom.com', 'dsanddurga.com',
#        'chefswarehouse.com', 'Danielscuderi.com', 'dartmedicallab.com',
#        'dasnymech.com', 'dcdad.com', 'habersilver.com', 'DTCC.com',
#        'db.com', 'ddp-ny.com', 'dinascorp.com', 'hotmail.com',
#        'drsmood.com', 'ducecc.com', 'dundyglass.com', 'jibei.com',
#        'ejork.com', 'interstate-envelope.com', 'gm-graphics.com',
#        'easterneffects.com', 'easterntabletop.com', 'eclecticprops.com',
#        'epl.com', 'emgmediainc.com', 'empressmam.com', 'epic-pharma.com',
#        'estee.com', 'storagedeluxe.com', 'evergreene.com',
#        'export-sales.com', 'fairwaymarket.com', 'fatwitch.com',
#        'faviana.com', 'fayda.com', 'fedex.com', 'fidelitypayment.com',
#        'cvmventures.com', 'foodfestdepot.com', 'fcrc.com',
#        'fraplaster.com', 'unionstreetstudiollc.com', 'freshdirect.com',
#        'manhattanfruitier.com', 'gailer.com', 'necsenergy.com',
#        'gcreate.com', 'globalterminals.com', 'corkfloor.com',
#        'goldsteincapital.com', 'gothamgreens.com', 'gourmetboutique.com',
#        'glarchiects.com', 'graham-windham.org', 'grandstandsports.com',
#        'officegreenfelds.com', 'grimmales.com', 'gustavrestoration.com',
#        'haleandhearty.com', 'vinegarhillhc.com',
#        'halmarkarchitectural.com', 'halo.com', 'hbsteel.com',
#        'heinsenproducts.com', 'herculesht.com', 'alo.com',
#        'highlinestages.com', 'hgstones.com', 'millerblaker.com',
#        'mrtcarting.com', 'houseofspicesindia.com', 'icloud.com',
#        'heyhush.com', 'hydromx', 'maliamills.com', 'idlelectric.com',
#        'iehcorp.com', 'ikea.com', 'innergaze.com', 'insekdesign.com',
#        'ArtexFAS.com', 'galwein.com', 'jandjjohnson.com', 'optonline.net',
#        'jcrew.com', 'mrchocolate.com', 'janusproperty.com',
#        'johnsnyc.com', 'Jetblue.com', 'jetrord.com', 'jprmechanical.com',
#        'justbagels.com', 'us.klinelogistics.com', 'sureiron.com',
#        'usa.com', 'karrgraphics.com', 'thekatirollcompany.com',
#        'kaufmanastoria.com', 'kickstarter.com', 'am.kwe.com',
#        'kflawny.com', 'Krinos.com', 'lafarge-na.com', 'lafayette148.com',
#        'lafgrind.com', 'leespring.com', 'liquid8technology.net',
#        'horizonmills.net', 'livestream.com', 'proaudiostar.com',
#        'longislandconcrete.net', 'mandrcpas.com', 'madamepaulette.com',
#        'madelainechocolate.com', 'magellan.aero', 'mecny.com',
#        'mariebelle.com', 'maricmechanical.com', 'marinaicecream.com',
#        'marjam.com', 'matros.com', 'cmcinnis.com', 'mechoshade.com',
#        'corfufoods.com', 'MESORAH.COM', 'mcfina.com', 'mkjcomm.com',
#        'gomondial.com', 'montebellofoods.com', 'montefiore.org',
#        'mytworks.com', 'nationalacoustics.com', 'nationaltextile.net',
#        'kaufmanshoe.com', 'natuzzibrosice.com', 'jansproperty.com',
#        'neumanskitch.com', 'newconceptsllc.com', 'heydenryk.com',
#        'palacepaints.com', 'nybc.org', 'nydigitalcolor.com', 'nyfusa.com',
#        'takecareof.com', 'novaprinting.com', 'adenovarebiologistics.com',
#        'noveltycrystal.com', 'NovoArts.com', 'nulux.com',
#        'artimusnyc.com', 'ohnuts.com', 'onegirlcookies.com',
#        'otherhalfbrewing.com', 'orwashers.com', 'paindavignon-nyc.com',
#        'paperenterprises.com', 'paralleldevelopment.net', 'optimum.net',
#        'parsons-meares.com', 'empiremerchants.com', 'raviolistore.com',
#        'pepsi-ny.com', 'petcarerx.com', 'forbee.com',
#        'picturefarmpro.com', 'pintoandtegerelectric.com', 'pdoinc.com',
#        'truepill.com', 'presentationproducts.com', 'nicka.com',
#        'qualitycasting.com', 'lightsup.info', 'rainbowplasticsinc.com',
#        'rdsdelivery.com', 'financierpastries.com', 'myredrabbit.com',
#        'rph.nyc', 'digitallaundry.net', 'rogerssurveying.com', 'rusa.com',
#        'catbirdnyc.com', 'mac.com', 'eliteairlineservices.com',
#        'missgrimble.com', 'russanddaughters.com', 'rwsandassociates.com',
#        'slaerospace.com', 'safeart.com', 'sculpturehousecasting.com',
#        'sdcdesigns.com', 'signsanddecal.com', 'sillyphillie.com',
#        'silverhillarts.com', 'siminternational.com', 'simdev.com',
#        'tradesupplygroup.com', 'influencegraphics.com',
#        'colossalmediagroup.com', 'skylinerestoration.com',
#        'skylinewindows.com', 'soharlem.org', 'spaethdesign.com',
#        'charter.com', 'spinmaster.com', 'squarerootsgrow.com',
#        'foodtravelexperts.com', 'stallionnyc.com', 'standandbuild.com',
#        'stinkstudio.com', 'brooklyngrangefarm.com', 'sweetsams.com',
#        'talasonline.com', 'teigroup.com', 'thebronxbrewery.com',
#        'dime.com', 'gluckplus.com', 'handytool.com', 'lobsterplace.com',
#        'gtmachinetool.com', 'nyu.edu', 'titone.com', 'tonerquest.com',
#        'tracywatts.com', 'ultraflex.com', 'transmitterbrewing.com',
#        'ceqy.com', 'triplumbing.com', 'pepsico.com', 'tmitrading.com',
#        'Twoseven.net', 'ulano.com', 'unitedair.com', 'unfcu.com',
#        'uwgny.com', 'urbanarchaeology.com', 'urbangreenfurniture.com',
#        'usta.com', 'vbcpkg.com', 'vaynermedia.com', 'vera.org',
#        'petrossian.com', 'vnsny.org', 'prattindustries.com',
#        'vivatime.com', 'w-architecture.com', 'waterliliesfood.com',
#        'watermark-designs.com', 'weaponspecialists.com',
#        'werwaissandco.com', 'harlembiospace.com', 'whitecoffee.com',
#        'acmesalesgroup.com', 'prodigy.net', 'wildedibles.com',
#        'hirdco.com', 'WSGC.com', 'wontonfood.com', 'wwps.com',
#        'wudfurniture.com', 'wurtec.com'], dtype=object)

# %%
# 4. Considering only NTAs with at least 5 listed businesses, what is the average total savings and the total jobs created for each NTA?

df_nyc = pd.read_csv(fpath + fname)
df_nyc['NTA'].value_counts()
# Out:
# Hunters Point-Sunnyside-West Maspeth        75
# Sunset Park West                            48
# Queensbridge-Ravenswood-Long Island City    16
# park-cemetery-etc-Brooklyn                  15
# Greenpoint                                  14
#                                             ..
# Washington Heights South                     1
# Forest Hills                                 1
# Morrisania-Melrose                           1
# Ocean Hill                                   1
# Co-op City                                   1
# Name: NTA, Length: 79, dtype: int64

# %%
# this returns the number of companies within each NTA
counts = df_nyc[['Company Name','NTA']].groupby('NTA').count()
counts
# Out:
#                                    Company Name
# NTA
# Astoria                                       3
# Baisley Park                                  1
# Battery Park City-Lower Manhattan             9
# Bedford                                       3
# Bensonhurst West                              1
# ...                                         ...
# Whitestone                                    3
# Williamsburg                                  1
# Windsor Terrace                               1
# Woodside                                      3
# park-cemetery-etc-Brooklyn                   15
#
# [79 rows x 1 columns]

# %%
check = counts[counts['Company Name'].ge(5)]
check['Company Name'].sum()
# Out:
# 306

# %%
# collect all ntas with at least 5 listed businesses:
ntas = counts[counts['Company Name'].ge(5)].index
ntas = list(ntas)
len(ntas)
# Out:
# 20

# %%
# write a fxn to check if value is in ntas:

def check_nta(nta,ntas):
    tf = bool()
    if nta in ntas:
        tf = True
    else:
        tf = False
    return tf

#df_nyc.loc[df_nyc['NTA'] in ntas]
ntas_5 = df_nyc[df_nyc['NTA'].apply(check_nta,args = (ntas,))]
ntas_5
# Out:
#                                  Company Name    company contact  \
# 1                              100 Church LLC  Edward A. Carroll
# 2                        100 Wall Investments       Jerry Branam
# 3                 1-10 Bush Terminal Owner LP     Andrew Kimball
# 4    120 Broadway Acquisitions JV, LLC (Ldmk)        Carl Letich
# 5                        120 Wall Street, LLC      Jason McCalla
# ..                                        ...                ...
# 443                  William Hird & Co., Inc.     Thomas E. Bury
# 444                     Williams Sonoma, Inc.  Christine Hickman
# 445                         WONTON FOOD, INC.         DONALD LAU
# 446                                Wood Works       Gordon Brawm
# 448                         WUD Furniture LLC     Keren Springer
#
#                  company email company phone                Address      City  \
# 1                          NaN    2125663000      100 Church Street        NY
# 2                          NaN    2122487160         96 Wall Street  New York
# 3    akimball@industrycity.com    3474178429  220 36th St, Suite 2A  Brooklyn
# 4        clettich@silvprop.com    2124064020           120 Broadway  New York
# 5        jmccalla@silvprop.com    2125517391        120 Wall Street  New York
# ..                         ...           ...                    ...       ...
# 443          tebury@hirdco.com    7184994881        255 40th Street  Brooklyn
# 444          CHickman@WSGC.com    7187804442        55 Water Street  Brooklyn
# 445   donaldlau@wontonfood.com    7186286868  220-222  MOORE STREET  Brooklyn
# 446       brawnworks@gmail.com    9179404950        162 Cook Street  Brooklyn
# 448     keren@wudfurniture.com    7184867952   1102 Atlantic Avenue  Brooklyn
#
#     State  Postcode                          Industry  \
# 1      NY     10007                        Commercial
# 2      NY     10005                          Landlord
# 3      NY     11232                          Landlord
# 4      NY     10271                        Commercial
# 5      NY     10005                        Commercial
# ..    ...       ...                               ...
# 443    NY     11232                     Manufacturing
# 444    NY     11201  Wholesale/Warehouse/Distribution
# 445    NY     11206                     Manufacturing
# 446    NY     11206                     Manufacturing
# 448    NY     11238                     Manufacturing
#
#                                         Industry descr  ...  \
# 1                                            21 Floors  ...
# 2                                                  NaN  ...
# 3    Special Eligible Premises for eligible businesses  ...
# 4                                                  NaN  ...
# 5                                         Back Offices  ...
# ..                                                 ...  ...
# 443                Manufacture fire protection systems  ...
# 444                 high quality products for the home  ...
# 445                          MFG. PASTA, EGGROLL SKINS  ...
# 446                        Installer of wood furniture  ...
# 448  We make handcrafted furniture, surfaces, lighting  ...
#
#     Savings from beginning receiving benefits   Borough   Latitude  Longitude  \
# 1                                4,423,698.05  New York  40.712968 -74.009490
# 2                                1,814,542.62  New York  40.705052 -74.007199
# 3                                    6,755.31  Brooklyn  40.656061 -74.007334
# 4                                3,293,055.08  New York  40.708546 -74.011041
# 5                                2,090,906.36  New York  40.704380 -74.006427
# ..                                        ...       ...        ...        ...
# 443                                 36,644.27  Brooklyn  40.653997 -74.009925
# 444                                 56,547.18  Brooklyn  40.703301 -73.992047
# 445                                965,843.58  Brooklyn  40.704425 -73.936010
# 446                                   3,585.4  Brooklyn  40.702869 -73.936466
# 448                                 12,287.32  Brooklyn  40.679518 -73.956819
#
#     Community Board Council District Census Tract        BIN           BBL  \
# 1             101.0              1.0         21.0  1001409.0  1.001250e+09
# 2             101.0              1.0          7.0  1000875.0  1.000380e+09
# 3             307.0             38.0          2.0  3398687.0  3.006950e+09
# 4             101.0              1.0          7.0  1001026.0  1.000478e+09
# 5             101.0              1.0          7.0  1000871.0  1.000370e+09
# ..              ...              ...          ...        ...           ...
# 443           307.0             38.0          2.0  3010468.0  3.007070e+09
# 444           302.0             33.0         21.0  3000019.0  3.000260e+09
# 445           301.0             34.0        485.0  3071539.0  3.031090e+09
# 446           301.0             34.0        485.0  3071625.0  3.031230e+09
# 448           308.0             35.0        305.0  3027572.0  3.011260e+09
#
#                                                   NTA
# 1              SoHo-TriBeCa-Civic Center-Little Italy
# 2                   Battery Park City-Lower Manhattan
# 3                                    Sunset Park West
# 4                   Battery Park City-Lower Manhattan
# 5                   Battery Park City-Lower Manhattan
# ..                                                ...
# 443                                  Sunset Park West
# 444  DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill
# 445                                    Bushwick South
# 446                                    Bushwick South
# 448                               Crown Heights North
#
# [306 rows x 26 columns]

# %%
ntas_5 = ntas_5[['Total Savings','Job created','NTA']]

#Total Savings is a string with commas - remove the commas and convert to a number

ntas_5 = ntas_5.assign(Total_Savings = ntas_5['Total Savings'].apply(lambda x: float(x.replace(",",""))))
ntas_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 306 entries, 1 to 448
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Total Savings  306 non-null    object
#  1   Job created    9 non-null      float64
#  2   NTA            306 non-null    object
#  3   Total_Savings  306 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 12.0+ KB

# %%
jc = ntas_5.groupby('NTA').sum()['Job created']
jc
# Out:
# NTA
# Battery Park City-Lower Manhattan                    0.0
# Bushwick South                                      10.0
# Carroll Gardens-Columbia Street-Red Hook             0.0
# College Point                                        2.0
# Crown Heights North                                  0.0
# DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill     0.0
# East New York                                       15.0
# East Williamsburg                                    0.0
# Greenpoint                                           0.0
# Hunters Point-Sunnyside-West Maspeth                 0.0
# Hunts Point                                         12.0
# Manhattanville                                       0.0
# Maspeth                                             10.0
# Mott Haven-Port Morris                              10.0
# Queensbridge-Ravenswood-Long Island City             0.0
# SoHo-TriBeCa-Civic Center-Little Italy               0.0
# Springfield Gardens South-Brookville                 0.0
# Steinway                                            20.0
# Sunset Park West                                     0.0
# park-cemetery-etc-Brooklyn                           0.0
# Name: Job created, dtype: float64

# %%
avgts = ntas_5.groupby('NTA').mean()['Total_Savings']
avgts = pd.DataFrame(avgts)
avgts
# Out:
#                                                   Total_Savings
# NTA
# Battery Park City-Lower Manhattan                 469890.796667
# Bushwick South                                     26140.455000
# Carroll Gardens-Columbia Street-Red Hook           24337.390000
# College Point                                      17159.372857
# Crown Heights North                                 4036.298889
# DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill   59950.340000
# East New York                                      48433.093333
# East Williamsburg                                  13990.626364
# Greenpoint                                          9753.649286
# Hunters Point-Sunnyside-West Maspeth               23931.398933
# Hunts Point                                        39246.016154
# Manhattanville                                      2760.888889
# Maspeth                                             6658.283333
# Mott Haven-Port Morris                             17843.937857
# Queensbridge-Ravenswood-Long Island City           61830.770625
# SoHo-TriBeCa-Civic Center-Little Italy             37214.024000
# Springfield Gardens South-Brookville               17757.662000
# Steinway                                           11227.155714
# Sunset Park West                                   14316.976875
# park-cemetery-etc-Brooklyn                         14327.419333

# %%
df_final = avgts.assign(Total_Jobs_Created = jc)
df_final = df_final.rename(columns = {'Total_Savings': 'Avg_Total_Savings'})
df_final
# Out:
#                                                   Avg_Total_Savings  \
# NTA
# Battery Park City-Lower Manhattan                     469890.796667
# Bushwick South                                         26140.455000
# Carroll Gardens-Columbia Street-Red Hook               24337.390000
# College Point                                          17159.372857
# Crown Heights North                                     4036.298889
# DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill       59950.340000
# East New York                                          48433.093333
# East Williamsburg                                      13990.626364
# Greenpoint                                              9753.649286
# Hunters Point-Sunnyside-West Maspeth                   23931.398933
# Hunts Point                                            39246.016154
# Manhattanville                                          2760.888889
# Maspeth                                                 6658.283333
# Mott Haven-Port Morris                                 17843.937857
# Queensbridge-Ravenswood-Long Island City               61830.770625
# SoHo-TriBeCa-Civic Center-Little Italy                 37214.024000
# Springfield Gardens South-Brookville                   17757.662000
# Steinway                                               11227.155714
# Sunset Park West                                       14316.976875
# park-cemetery-etc-Brooklyn                             14327.419333
#
#                                                   Total_Jobs_Created
# NTA
# Battery Park City-Lower Manhattan                                0.0
# Bushwick South                                                  10.0
# Carroll Gardens-Columbia Street-Red Hook                         0.0
# College Point                                                    2.0
# Crown Heights North                                              0.0
# DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill                 0.0
# East New York                                                   15.0
# East Williamsburg                                                0.0
# Greenpoint                                                       0.0
# Hunters Point-Sunnyside-West Maspeth                             0.0
# Hunts Point                                                     12.0
# Manhattanville                                                   0.0
# Maspeth                                                         10.0
# Mott Haven-Port Morris                                          10.0
# Queensbridge-Ravenswood-Long Island City                         0.0
# SoHo-TriBeCa-Civic Center-Little Italy                           0.0
# Springfield Gardens South-Brookville                             0.0
# Steinway                                                        20.0
# Sunset Park West                                                 0.0
# park-cemetery-etc-Brooklyn                                       0.0

# %%
# 5. Save your result for the previous question as a CSV file.
df_final.to_csv(fpath + 'Day4_Q5.csv', index = True)

# %%
# Day 5 exercises
import seaborn as sns
sns.set()

# standard scale for average savings:
sns.scatterplot(x='Avg_Total_Savings', y='Total_Jobs_Created', data=df_final, marker='+')
# Out:
# <AxesSubplot:xlabel='Avg_Total_Savings', ylabel='Total_Jobs_Created'>

# %%
# do the same using matplotlib
import matplotlib.pyplot as plt

plt.plot(df_final['Avg_Total_Savings'], df_final['Total_Jobs_Created'], 'o', color='k');
plt.xlabel('Average Total Savings ($)')
plt.ylabel('Total Jobs Created');

# %%
# logarithmic scale for average savings:
import numpy as np
logx = np.log(df_final['Avg_Total_Savings'])

sns.scatterplot(x=logx, y='Total_Jobs_Created', data=df_final, marker='+')
# Out:
# <AxesSubplot:xlabel='Avg_Total_Savings', ylabel='Total_Jobs_Created'>

# %%
# histogram of the log of the average total savings
plt.hist(logx, bins=32)

# Add some formatting to the plot:
plt.xlabel('Average Total Savings (log)')
plt.ylabel('Number of observations')
plt.title('Log of Average Total Savings Histogram');

# %%
# line plot of the total jobs created for each month
jobs = df_nyc[['Job created','Effective Date']]
jobs.head()
# Out:
#    Job created Effective Date
# 0          NaN     03/04/2005
# 1          NaN     04/02/2008
# 2          NaN     01/05/2015
# 3          NaN     02/03/2020
# 4          NaN     06/30/2017

# %%
# convert effective date to time series:
jobs["Effective Date"] = pd.to_datetime(jobs["Effective Date"])
jobs.head()
# Out:
# C:\Users\Bizon\AppData\Local\Temp\ipykernel_9884\1731421754.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobs["Effective Date"] = pd.to_datetime(jobs["Effective Date"])
#    Job created Effective Date
# 0          NaN     2005-03-04
# 1          NaN     2008-04-02
# 2          NaN     2015-01-05
# 3          NaN     2020-02-03
# 4          NaN     2017-06-30

# %%
jobs['Effective Date'].value_counts()
# Out:
# 2019-04-19    5
# 2015-07-08    4
# 2015-07-06    4
# 2015-07-02    4
# 2013-07-03    4
#              ..
# 2010-04-22    1
# 2016-02-23    1
# 2015-11-04    1
# 2016-10-17    1
# 2019-10-03    1
# Name: Effective Date, Length: 366, dtype: int64

# %%
#groupby effective date and sum jobs for total:
grouped_jobs = jobs.groupby('Effective Date').sum()
grouped_jobs
# Out:
#                 Job created
# Effective Date
# 1993-02-05             15.0
# 2004-03-05             10.0
# 2005-02-03             12.0
# 2005-03-04              0.0
# 2005-06-30              0.0
# ...                     ...
# 2020-05-12              0.0
# 2020-06-04              0.0
# 2020-06-05              0.0
# 2020-06-29              0.0
# 2020-07-07              0.0
#
# [366 rows x 1 columns]

# %%
grouped_jobs.plot()
plt.ylabel('Total Jobs Created');

# %%
# above is not accurate because it does not account for every month and is not summed within month: need to resample
monthly_jobs = grouped_jobs.resample('M').sum()
monthly_jobs
# Out:
#                 Job created
# Effective Date
# 1993-02-28             15.0
# 1993-03-31              0.0
# 1993-04-30              0.0
# 1993-05-31              0.0
# 1993-06-30              0.0
# ...                     ...
# 2020-03-31              0.0
# 2020-04-30              0.0
# 2020-05-31              0.0
# 2020-06-30              0.0
# 2020-07-31              0.0
#
# [330 rows x 1 columns]

# %%
monthly_jobs = monthly_jobs.rename(columns = {'Job Created': 'Jobs Created'})
monthly_jobs.plot()
plt.ylabel('Total Number of Jobs Created');
